# %% [markdown]
# # Test de l''environnement deep5
#
# Ce notebook verifie que toutes les dependances necessaires au projet sont disponibles dans le noyau `deep5` (Python 3.12, TensorFlow 2.21, scikit-learn 1.9).
#
#
# **A executer en premier** avant de copier les questions 1 a 4.

# %%
# --- Versions Python et packages ---------------------------------------------
import sys
print(f"Python      : {sys.version}")
print(f"Executables : {sys.executable}\n")

import tensorflow as tf
import keras
print(f"TensorFlow  : {tf.__version__}")
print(f"Keras       : {keras.__version__}")
gpus = tf.config.list_physical_devices("GPU")
print(f"GPU dispo   : {len(gpus) > 0} ({len(gpus)} GPU detecte(s))\n")

import sklearn, scikeras
from scikeras.wrappers import KerasClassifier
print(f"scikit-learn: {sklearn.__version__}")
print(f"scikeras    : {scikeras.__version__}\n")

import datasets, numpy, pandas, matplotlib, seaborn
from PIL import Image
print(f"datasets    : {datasets.__version__}")
print(f"NumPy       : {numpy.__version__}")
print(f"Pandas      : {pandas.__version__}")
print(f"Matplotlib  : {matplotlib.__version__}")
print(f"Seaborn     : {seaborn.__version__}")
print(f"Pillow      : {Image.__version__}")

print("\n>> Toutes les dependances sont chargees.")
